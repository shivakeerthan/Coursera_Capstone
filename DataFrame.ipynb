# %%
import pandas as pd

# %%
from lxml import html
import requests

# %%
page = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
tree = html.fromstring(page.content)

# %%
tree
# Out:
# <Element html at 0x188425e3098>

# %%
pip install requests
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install requests
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
exit()

# %%
import requests

# %%
import lxml

# %%
import bs4

# %%
res=requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')

# %%
type(res)
# Out:
# requests.models.Response

# %%
soup=bs4.BeautifulSoup(res.text,'lxml')

# %%
table=soup.select('table')

# %%
l=[]
k=[]

# %%
table1=soup.select('td')

# %%
for i in table1:
    l.append(i.text)

# %%
theList = list(range(863))
N=3

# %%
subList = [l[n:n+N] for n in range(0, len(l), N)]

# %%
subList[287][1]
# Out:
# 'Not assigned'

# %%
a=[]
b=[]
c=[]
for x in range(0,287):
    a.append(subList[x][0])

# %%
import pandas as pd
df1=pd.DataFrame(a)
df1.head()
# Out:
#      0
# 0  M1A
# 1  M2A
# 2  M3A
# 3  M4A
# 4  M5A

# %%
c=[]
for y in range(0,287):
    c.append(subList[y][1])

# %%
df2=pd.DataFrame(c)
df2.head()
# Out:
#                   0
# 0      Not assigned
# 1      Not assigned
# 2        North York
# 3        North York
# 4  Downtown Toronto

# %%
d=[]
for z in range(0,287):
    d.append(subList[z][2])

# %%
df3=pd.DataFrame(d)
df3.head()
# Out:
#                     0
# 0      Not assigned\n
# 1      Not assigned\n
# 2         Parkwoods\n
# 3  Victoria Village\n
# 4      Harbourfront\n

# %%
d=pd.concat([df1,df2],axis=1)

# %%
df=pd.concat([d,df3],axis=1)
df.head()
# Out:
#      0                 0                   0
# 0  M1A      Not assigned      Not assigned\n
# 1  M2A      Not assigned      Not assigned\n
# 2  M3A        North York         Parkwoods\n
# 3  M4A        North York  Victoria Village\n
# 4  M5A  Downtown Toronto      Harbourfront\n

# %%
df.head(index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-16c535a48348> in <module>()
# ----> 1 df.head(index=False)
#
# TypeError: head() got an unexpected keyword argument 'index'

# %%
df.columns=['postcode','borough','Neighborhood']

# %%
df.head()
# Out:
#   postcode           borough        Neighborhood
# 0      M1A      Not assigned      Not assigned\n
# 1      M2A      Not assigned      Not assigned\n
# 2      M3A        North York         Parkwoods\n
# 3      M4A        North York  Victoria Village\n
# 4      M5A  Downtown Toronto      Harbourfront\n

# %%
df2=df[df['borough']!='Not assigned']

# %%
df2[df2['Neighborhood']=='Not assigned\n']
# Out:
#   postcode       borough    Neighborhood
# 8      M7A  Queen's Park  Not assigned\n

# %%
df2.at[8,'Neighborhood']="Queen's Park"

# %%
df2[df2['borough']=='Not assigned\n']
# Out:
# Empty DataFrame
# Columns: [postcode, borough, Neighborhood]
# Index: []

# %%
d=df2[['postcode','borough']].groupby(['postcode']).sum()

# %%
d['borough'].replace(to_replace='ScarboroughScarborough',value='Scarborough',inplace=True)

# %%
d['borough'].replace(to_replace='ScarboroughScarboroughScarborough',value='Scarborough',inplace=True)
d.head()
# Out:
#               borough
# postcode
# M1B       Scarborough
# M1C       Scarborough
# M1E       Scarborough
# M1G       Scarborough
# M1H       Scarborough

# %%
d['borough'].replace(to_replace='ScarboroughScarboroughScarboroughScarborough',value='Scarborough',inplace=True)

# %%
d['borough'].replace(to_replace='North YorkNorth York',value='North York',inplace=True)

# %%
d['borough'].replace(to_replace='North YorkNorth YorkNorth York',value='North York',inplace=True)

# %%
d['borough'].replace(to_replace='YorkYorkYorkYork',value='York',inplace=True)

# %%
d['borough'].replace(to_replace='YorkYork',value='York',inplace=True)

# %%
d['borough'].replace(to_replace='EtobicokeEtobicoke',value='Etobicoke',inplace=True)

# %%
d['borough'].replace(to_replace='Central TorontoCentral TorontoCentral TorontoCentral TorontoCentral Toronto',value='Central Toronto',inplace=True)

# %%
d['borough'].replace(to_replace='Downtown TorontoDowntown TorontoDowntown TorontoDowntown TorontoDowntown TorontoDowntown TorontoDowntown Toronto',value='Downtown Toronto',inplace=True)

# %%
d['borough'].replace(to_replace='Central TorontoCentral TorontoCentral Toronto',value='Central Toronto',inplace=True)

# %%
d['borough'].replace(to_replace='East YorkEast York',value='East York',inplace=True)

# %%
d
# Out:
#                    borough
# postcode
# M1B            Scarborough
# M1C            Scarborough
# M1E            Scarborough
# M1G            Scarborough
# M1H            Scarborough
# M1J            Scarborough
# M1K            Scarborough
# M1L            Scarborough
# M1M            Scarborough
# M1N            Scarborough
# M1P            Scarborough
# M1R            Scarborough
# M1S            Scarborough
# M1T            Scarborough
# M1V            Scarborough
# M1W            Scarborough
# M1X            Scarborough
# M2H             North York
# M2J             North York
# M2K             North York
# M2L             North York
# M2M             North York
# M2N             North York
# M2P             North York
# M2R             North York
# M3A             North York
# M3B             North York
# M3C             North York
# M3H             North York
# M3J             North York
# ...                    ...
# M6C                   York
# M6E                   York
# ...

# %%
df3=df2.groupby(['postcode']).sum()
df3.head(20)
# Out:
#                                                borough  \
# postcode
# M1B                             ScarboroughScarborough
# M1C                  ScarboroughScarboroughScarborough
# M1E                  ScarboroughScarboroughScarborough
# M1G                                        Scarborough
# M1H                                        Scarborough
# M1J                                        Scarborough
# M1K                  ScarboroughScarboroughScarborough
# M1L                  ScarboroughScarboroughScarborough
# M1M                  ScarboroughScarboroughScarborough
# M1N                             ScarboroughScarborough
# M1P                  ScarboroughScarboroughScarborough
# M1R                             ScarboroughScarborough
# M1S                                        Scarborough
# M1T                  ScarboroughScarboroughScarborough
# M1V       ScarboroughScarboroughScarboroughScarborough
# M1W                                        Scarborough
# ...

# %%
df4=df3['Neighborhood'].str.split("\n")

# %%
df4=pd.DataFrame(df4)

# %%
df4.head()
# Out:
#                                         Neighborhood
# postcode
# M1B                               [Rouge, Malvern, ]
# M1C       [Highland Creek, Rouge Hill, Port Union, ]
# M1E            [Guildwood, Morningside, West Hill, ]
# M1G                                       [Woburn, ]
# M1H                                    [Cedarbrae, ]

# %%
df5=df4.copy()

# %%
#for i in df5['Neighborhood']:
    #print(i)
df100=df5[:'Neighborhood']  
df100=pd.DataFrame(df100)
df100.head()
# Out:
#                                       Neighborhood
# postcode
# M1B                               [Rouge, Malvern]
# M1C       [Highland Creek, Rouge Hill, Port Union]
# M1E            [Guildwood, Morningside, West Hill]
# M1G                                       [Woburn]
# M1H                                    [Cedarbrae]

# %%
df9=pd.DataFrame()
df100
# Out:
#                                                Neighborhood
# postcode
# M1B                                        [Rouge, Malvern]
# M1C                [Highland Creek, Rouge Hill, Port Union]
# M1E                     [Guildwood, Morningside, West Hill]
# M1G                                                [Woburn]
# M1H                                             [Cedarbrae]
# M1J                                   [Scarborough Village]
# M1K           [East Birchmount Park, Ionview, Kennedy Park]
# M1L                       [Clairlea, Golden Mile, Oakridge]
# M1M       [Cliffcrest, Cliffside, Scarborough Village West]
# M1N                           [Birch Cliff, Cliffside West]
# M1P       [Dorset Park, Scarborough Town Centre, Wexford...
# M1R                                     [Maryvale, Wexford]
# M1S                                             [Agincourt]
# M1T               [Clarks Corners, Sullivan, Tam O'Shanter]
# ...

# %%
nfinal=pd.merge(left=d,right=df100,left_index=True,right_index=True)

# %%
nfinal.at['M7A',"Neighborhood"]="Queen's Park"

# %%
n1final=nfinal.copy()

# %%
str(n1final['Neighborhood'][1]).replace('[','')
# Out:
# "'Highland Creek', 'Rouge Hill', 'Port Union']"

# %%
p=[1,2,3]
k=str(p)
k.replace('[','')
k.replace(']','')
# Out:
# '[1, 2, 3'

# %%
neighborhood=df4['Neighborhood']
dfn=pd.DataFrame()

# %%
nfinal
# Out:
#                    borough                                       Neighborhood
# postcode
# M1B            Scarborough                                   [Rouge, Malvern]
# M1C            Scarborough           [Highland Creek, Rouge Hill, Port Union]
# M1E            Scarborough                [Guildwood, Morningside, West Hill]
# M1G            Scarborough                                           [Woburn]
# M1H            Scarborough                                        [Cedarbrae]
# M1J            Scarborough                              [Scarborough Village]
# M1K            Scarborough      [East Birchmount Park, Ionview, Kennedy Park]
# M1L            Scarborough                  [Clairlea, Golden Mile, Oakridge]
# M1M            Scarborough  [Cliffcrest, Cliffside, Scarborough Village West]
# M1N            Scarborough                      [Birch Cliff, Cliffside West]
# M1P            Scarborough  [Dorset Park, Scarborough Town Centre, Wexford...
# ...
